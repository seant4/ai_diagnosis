# %%
import numpy as np
import pandas as pd
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/dataset.csv")
symptoms = data.drop(['Disease'], axis=1)
symptom_results = list(set(symptoms.values.flatten()))
symptom_results

##Update the dataset with this new data
data_new = data
data_new.head()
for i in range(len(symptom_results)):
    data_new = data_new.replace(symptom_results[i], i)
x_train = data_new.drop(['Disease'], axis=1)
y_labels = list(set(data_new['Disease'].values.flatten()))
y_train = data['Disease']
for i in range(len(y_labels)):
    y_train = y_train.replace(y_labels[i], i)
y_train

def one_hot_encoding(data):
    encoded_data = to_categorical(data)
    return encoded_data

# %%
pd.DataFrame(y_labels).to_csv('y_labels.zip', index=False)

# %%
x_train = pd.read_csv("data/x_train.csv")
y_train = pd.read_csv("data/y_train.csv")

x_train
# Out:
#       Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  Symptom_6  \
# 0            84         55        114        116         81         81
# 1            55        114        116         81         81         81
# 2            84        114        116         81         81         81
# 3            84         55        116         81         81         81
# 4            84         55        114         81         81         81
# ...         ...        ...        ...        ...        ...        ...
# 4915         98         82         86         37         70         73
# 4916         55         26         30        108         81         81
# 4917         57         83         93         74         81         81
# 4918         55        104         42         19         13         38
# 4919         55         44          6        106        119         81
#
#       Symptom_7  Symptom_8  Symptom_9  Symptom_10  Symptom_11  Symptom_12  \
# ...

# %%
y_labels_updated = pd.read_csv('data/y_labels.csv')
y_labels_updated = y_labels_updated.values.tolist()
y_labels_updated = [i[0] for i in y_labels_updated]
x_labels_updated = pd.read_csv('data/x_labels.csv')
x_labels_updated = x_labels_updated.values.tolist()
x_labels_updated = [i[0] for i in x_labels_updated]
x_labels_updated = [i for i in x_labels_updated]
x_train
# Out:
# array([[ 84.,  55., 114., ...,  81.,  81.,  81.],
#        [122.,  16.,  10., ...,  81.,  81.,  81.],
#        [ 25.,  92.,  27., ...,  81.,  81.,  81.],
#        ...,
#        [ 92.,  78.,  82., ...,  81.,  81.,  81.],
#        [111., 103.,  86., ...,  81.,  81.,  81.],
#        [111.,  50., 109., ...,  81.,  81.,  81.]])
